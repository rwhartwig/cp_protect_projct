# %% [markdown]
# # Spectrum Protect Summary Table Analysis
#
# Created by: Robert Hartwig
# Last edited:  November 25, 2020
# Verison: 1.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download a sample Spectrum Protect summary table from IBM Cloud bucket.

# %%
# !wget -O summary.txt https://cp-protect-project.s3.us-east.cloud-object-storage.appdomain.cloud/summary.txt
# Out:
# --2020-11-25 17:27:06--  https://cp-protect-project.s3.us-east.cloud-object-storage.appdomain.cloud/summary.txt
# Resolving cp-protect-project.s3.us-east.cloud-object-storage.appdomain.cloud (cp-protect-project.s3.us-east.cloud-object-storage.appdomain.cloud)... 169.63.118.98
# Connecting to cp-protect-project.s3.us-east.cloud-object-storage.appdomain.cloud (cp-protect-project.s3.us-east.cloud-object-storage.appdomain.cloud)|169.63.118.98|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4569083 (4.4M) [application/octet-stream]
# Saving to: ‘summary.txt’
#
# summary.txt         100%[===================>]   4.36M   943KB/s    in 5.4s
#
# 2020-11-25 17:27:12 (826 KB/s) - ‘summary.txt’ saved [4569083/4569083]

# %% [markdown]
# ### Load the summary.txt file into a dataframe.  Skipping the first 9 rows of the summary.txt as it is just comments.

# %%
df = pd.read_csv('summary.txt', skiprows=9, header=None)

# %% [markdown]
# ### Naming to the colums as using the following IBM Knowledge Center Spectrum Protect 7.1 page.
#
# https://www.ibm.com/support/knowledgecenter/SSGSG7_7.1.0/com.ibm.itsm.srv.doc/t_sql_activity_summ_tbl_querying.html

# %%
df.columns = ["START_TIME:", "END_TIME:", "ACTIVITY:", "NUMBER:", "ENTITY:", "COMMMETH:", "ADDRESS:", "SCHEDULE_NAME:", "EXAMINED:", "AFFECTED:", "FAILED:", "BYTES:", "IDLE:", "MEDIAW:", "PROCESSES:", "SUCCESSFUL:", "VOLUME_NAME:", "DRIVE_NAME:", "LIBRARY_NAME:", "LAST_USE:", "COMM_WAIT:", "NUM_OFFSITE_VOLS:"]

# %% [markdown]
# ### Get the number of rows and colums in the dataframe

# %%
df.shape
# Out:
# (35910, 22)

# %%
df.sort_values(by=['START_TIME:'], ascending=True)
# Out:
#                       START_TIME:                   END_TIME:       ACTIVITY:  \
# 8258   2016-11-06 00:00:44.000000  2016-11-06 00:04:53.000000          BACKUP
# 8267   2016-11-06 00:00:44.000000  2016-11-06 00:00:51.000000          BACKUP
# 8266   2016-11-06 00:01:00.000000  2016-11-06 00:01:02.000000          BACKUP
# 8268   2016-11-06 00:01:02.000000  2016-11-06 00:01:07.000000          BACKUP
# 8257   2016-11-06 00:04:53.000000  2016-11-06 00:04:55.000000          BACKUP
# ...                           ...                         ...             ...
# 35890  2016-12-06 15:51:37.000000  2016-12-06 15:51:37.000000  POOLPRIMUTILGB
# 35887  2016-12-06 15:51:37.000000  2016-12-06 15:51:37.000000  POOLPRIMUTILGB
# 35886  2016-12-06 15:51:37.000000  2016-12-06 15:51:37.000000  POOLCOPYUTILGB
# 35899  2016-12-06 15:51:37.000000  2016-12-06 15:51:37.000000  POOLPRIMUTILGB
# 35889  2016-12-06 15:51:37.000000  2016-12-06 15:51:37.000000  POOLPRIMUTILGB
#
#        NUMBER:                    ENTITY: COMMMETH:           ADDRESS:  \
# 8258   3470732   SQLCLUS03 (DC-SQL34_SQL)    Tcp/Ip  172.31.2.97:52416
# 8267   3470733              SCS-SQL34_SQL    Tcp/Ip  172.25.2.55:60916
# 8266   3470744  SQLCLUS03 (SCS-SQL33_SQL)    Tcp/Ip  172.25.2.54:52635
# 8268   3470745              SCS-SQL33_SQL    Tcp/Ip  172.25.2.54:52636
# 8257   3470775               DC-SQL34_SQL    Tcp/Ip  172.31.2.97:52505
# ...        ...                        ...       ...                ...
# 35890        1                 BACKUPPOOL       NaN                NaN
# 35887        1         AGFA_LTO5_TAPEPOOL       NaN                NaN
# 35886        1         AGFA_LTO5_COPYPOOL       NaN                NaN
# 35899        1        NHS_ARCHIVE_PRIMARY       NaN                NaN
# 35889        1                ARCHIVEPOOL       NaN                NaN
#
#        SCHEDULE_NAME:  EXAMINED:  AFFECTED:  ...  IDLE:  MEDIAW:  PROCESSES:  \
# 8258   SQLLOGS_HOURLY          0         99  ...    212        0           1
# 8267   SQLLOGS_HOURLY          0          6  ...      6        0           1
# 8266   SQLLOGS_HOURLY          0          3  ...      1        0           1
# 8268   SQLLOGS_HOURLY          0          3  ...      4        0           1
# 8257   SQLLOGS_HOURLY          0          3  ...      1        0           1
# ...               ...        ...        ...  ...    ...      ...         ...
# 35890             NaN          0          0  ...      0        0           0
# 35887             NaN          0          0  ...      0        0           0
# 35886             NaN          0          0  ...      0        0           0
# 35899             NaN          0          0  ...      0        0           0
# 35889             NaN          0          0  ...      0        0           0
#
#        SUCCESSFUL:  VOLUME_NAME: DRIVE_NAME: LIBRARY_NAME: LAST_USE:  \
# 8258           YES           NaN         NaN           NaN       NaN
# 8267           YES           NaN         NaN           NaN       NaN
# 8266           YES           NaN         NaN           NaN       NaN
# 8268           YES           NaN         NaN           NaN       NaN
# 8257           YES           NaN         NaN           NaN       NaN
# ...            ...           ...         ...           ...       ...
# 35890          YES           NaN         NaN           NaN       NaN
# 35887          YES           NaN         NaN           NaN       NaN
# 35886          YES           NaN         NaN           NaN       NaN
# 35899          YES           NaN         NaN           NaN       NaN
# 35889          YES           NaN         NaN           NaN       NaN
#
#       COMM_WAIT: NUM_OFFSITE_VOLS:
# 8258        25.0               NaN
# 8267         0.0               NaN
# 8266         0.0               NaN
# 8268         0.0               NaN
# 8257         0.0               NaN
# ...          ...               ...
# 35890        0.0               NaN
# 35887        0.0               NaN
# 35886        0.0               NaN
# 35899        0.0               NaN
# 35889        0.0               NaN
#
# [35910 rows x 22 columns]

# %%
df.head()
# Out:
#                   START_TIME:                   END_TIME:       ACTIVITY:  \
# 0  2016-11-13 06:27:13.000000  2016-11-13 06:27:13.000000  POOLPRIMUTILGB
# 1  2016-11-13 07:00:32.000000  2016-11-13 07:59:50.000000      TAPE MOUNT
# 2  2016-11-13 07:00:07.000000  2016-11-13 07:55:58.000000  STGPOOL BACKUP
# 3  2016-11-13 08:35:14.000000  2016-11-13 08:35:14.000000  POOLPRIMUTILGB
# 4  2016-11-13 07:31:13.000000  2016-11-13 07:31:13.000000  POOLPRIMUTILGB
#
#    NUMBER:                     ENTITY: COMMMETH: ADDRESS: SCHEDULE_NAME:  \
# 0        1                 TEST_BACKUP       NaN      NaN            NaN
# 1        0                         NaN       NaN      NaN            NaN
# 2     4616  VE_BKPOOL -> COPYPOOL_LTO5       NaN      NaN    MAINTENANCE
# 3        1                TEST_ARCHIVE       NaN      NaN            NaN
# 4        1         NHS_ARCHIVE_PRIMARY       NaN      NaN            NaN
#
#    EXAMINED:  AFFECTED:  ...  IDLE:  MEDIAW:  PROCESSES:  SUCCESSFUL:  \
# 0          0          0  ...      0        0           0          YES
# 1          0          0  ...      0        0           0          YES
# 2      23938      23938  ...      0       28           1          YES
# 3          0          0  ...      0        0           0          YES
# 4          0          0  ...      0        0           0          YES
#
#    VOLUME_NAME:                DRIVE_NAME: LIBRARY_NAME: LAST_USE: COMM_WAIT:  \
# 0           NaN                        NaN           NaN       NaN        0.0
# 1      C00890L5  DRIVE10 (/dev/TDRIVE-R10)       3584LIB      Data        0.0
# 2           NaN                        NaN           NaN       NaN        0.0
# 3           NaN                        NaN           NaN       NaN        0.0
# 4           NaN                        NaN           NaN       NaN        0.0
#
#   NUM_OFFSITE_VOLS:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 22 columns]

# %%
list(df.columns)
# Out:
# ['START_TIME:',
#  'END_TIME:',
#  'ACTIVITY:',
#  'NUMBER:',
#  'ENTITY:',
#  'COMMMETH:',
#  'ADDRESS:',
#  'SCHEDULE_NAME:',
#  'EXAMINED:',
#  'AFFECTED:',
#  'FAILED:',
#  'BYTES:',
#  'IDLE:',
#  'MEDIAW:',
#  'PROCESSES:',
#  'SUCCESSFUL:',
#  'VOLUME_NAME:',
#  'DRIVE_NAME:',
#  'LIBRARY_NAME:',
#  'LAST_USE:',
#  'COMM_WAIT:',
#  'NUM_OFFSITE_VOLS:']

# %% [markdown]
# ### Convert the START_TIME and END_TIME from string to datetime format

# %%
df['START_TIME:'].astype('datetime64')
# Out:
# 0       2016-11-13 06:27:13
# 1       2016-11-13 07:00:32
# 2       2016-11-13 07:00:07
# 3       2016-11-13 08:35:14
# 4       2016-11-13 07:31:13
#                 ...
# 35905   2016-12-06 15:37:07
# 35906   2016-12-06 15:37:08
# 35907   2016-12-06 15:37:08
# 35908   2016-12-06 15:51:37
# 35909   2016-12-06 15:37:08
# Name: START_TIME:, Length: 35910, dtype: datetime64[ns]

# %% [markdown]
# ### Format the END_TIME field

# %%
df['END_TIME:'].astype('datetime64')
# Out:
# 0       2016-11-13 06:27:13
# 1       2016-11-13 07:59:50
# 2       2016-11-13 07:55:58
# 3       2016-11-13 08:35:14
# 4       2016-11-13 07:31:13
#                 ...
# 35905   2016-12-06 15:37:08
# 35906   2016-12-06 15:37:08
# 35907   2016-12-06 15:37:08
# 35908   2016-12-06 15:51:37
# 35909   2016-12-06 15:37:08
# Name: END_TIME:, Length: 35910, dtype: datetime64[ns]

# %% [markdown]
# ### Making sure the BYTES column is an integer so to calculate the sum of the daily bytes

# %%
df['BYTES:'].astype('int64')
# Out:
# 0                   0
# 1                   0
# 2        218545831936
# 3                   0
# 4                 110
#              ...
# 35905               0
# 35906               0
# 35907               0
# 35908               0
# 35909               0
# Name: BYTES:, Length: 35910, dtype: int64

# %% [markdown]
# ### Use the Pandas dt.normalize to format the date & time to calculate daily sums

# %%
df['START_TIME:'] = pd.to_datetime(df['START_TIME:']).dt.normalize()

# %%
df['END_TIME:'] = pd.to_datetime(df['END_TIME:']).dt.normalize()

# %%
df.head()
# Out:
#   START_TIME:  END_TIME:       ACTIVITY:  NUMBER:                     ENTITY:  \
# 0  2016-11-13 2016-11-13  POOLPRIMUTILGB        1                 TEST_BACKUP
# 1  2016-11-13 2016-11-13      TAPE MOUNT        0                         NaN
# 2  2016-11-13 2016-11-13  STGPOOL BACKUP     4616  VE_BKPOOL -> COPYPOOL_LTO5
# 3  2016-11-13 2016-11-13  POOLPRIMUTILGB        1                TEST_ARCHIVE
# 4  2016-11-13 2016-11-13  POOLPRIMUTILGB        1         NHS_ARCHIVE_PRIMARY
#
#   COMMMETH: ADDRESS: SCHEDULE_NAME:  EXAMINED:  AFFECTED:  ...  IDLE:  \
# 0       NaN      NaN            NaN          0          0  ...      0
# 1       NaN      NaN            NaN          0          0  ...      0
# 2       NaN      NaN    MAINTENANCE      23938      23938  ...      0
# 3       NaN      NaN            NaN          0          0  ...      0
# 4       NaN      NaN            NaN          0          0  ...      0
#
#    MEDIAW:  PROCESSES:  SUCCESSFUL:  VOLUME_NAME:                DRIVE_NAME:  \
# 0        0           0          YES           NaN                        NaN
# 1        0           0          YES      C00890L5  DRIVE10 (/dev/TDRIVE-R10)
# 2       28           1          YES           NaN                        NaN
# 3        0           0          YES           NaN                        NaN
# 4        0           0          YES           NaN                        NaN
#
#   LIBRARY_NAME: LAST_USE: COMM_WAIT: NUM_OFFSITE_VOLS:
# 0           NaN       NaN        0.0               NaN
# 1       3584LIB      Data        0.0               NaN
# 2           NaN       NaN        0.0               NaN
# 3           NaN       NaN        0.0               NaN
# 4           NaN       NaN        0.0               NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Sort and do a daily summary in the dataframe using the ACTIVITY columm using BACKUP as the search parameter.
# The first and last date are removed to give a more accerate analysis of the daily backup.

# %%
dbkup = df[df['ACTIVITY:'].str.match('BACKUP')].groupby('START_TIME:').sum().tail(-1).head(-1)

# %% [markdown]
# ### Covert bytes into terabytes

# %%
tb_dbkup = dbkup['BYTES:']/(1e+12)

# %%
tb_dbkup
# Out:
# START_TIME:
# 2016-11-07    1.956957
# 2016-11-08    2.186184
# 2016-11-09    1.931205
# 2016-11-10    1.889454
# 2016-11-11    2.319285
# 2016-11-12    1.720366
# 2016-11-13    1.752807
# 2016-11-14    1.980953
# 2016-11-15    1.947673
# 2016-11-16    2.332555
# 2016-11-17    1.890884
# 2016-11-18    2.136103
# 2016-11-19    1.774389
# 2016-11-20    1.794375
# 2016-11-21    1.915587
# 2016-11-22    2.152853
# 2016-11-23    1.963544
# 2016-11-24    1.968894
# 2016-11-25    2.071913
# 2016-11-26    1.862412
# 2016-11-27    1.787671
# 2016-11-28    1.989061
# 2016-11-29    1.976046
# 2016-11-30    2.005547
# 2016-12-01    2.001853
# 2016-12-02    2.113658
# 2016-12-03    1.824735
# 2016-12-04    1.830635
# 2016-12-05    3.400948
# Name: BYTES:, dtype: float64

# %% [markdown]
# ### Sort and do a daily summary in the dataframe using the ACTIVITY columm using RESTORE as the search parameter.

# %%
drestore = df[df['ACTIVITY:'].str.match('RESTORE')].groupby('START_TIME:').sum()

# %%
tb_drestore = drestore['BYTES:']/(1e+12)

# %%
tb_drestore
# Out:
# START_TIME:
# 2016-11-10    0.000965
# 2016-11-11    0.001529
# 2016-11-30    0.013285
# Name: BYTES:, dtype: float64

# %% [markdown]
# ### Using a line graph to plot the TB per day backup by this Spectrum Protect instance

# %%
tb_dbkup.plot(kind='bar', color='green' , linewidth=3.0 , figsize=(16,8))

plt.title("Spectrum Protect daily backup in TB", fontsize=24, color='blue')
plt.xlabel("Date", fontsize=16, color='red')
plt.ylabel("TB", fontsize=16, color='red')
# Out:
# Text(0, 0.5, 'TB')

# %% [markdown]
# ### Using a line graph to plot the TB per day restore by this Spectrum Protect instance

# %%
tb_drestore.plot(kind='bar', color='green' , linewidth=3.0 , figsize=(16,8))

plt.title("Spectrum Protect daily restored in TB", fontsize=24, color='blue')
plt.xlabel("Date", fontsize=16, color='red')
plt.ylabel("TB", fontsize=16, color='red')
# Out:
# Text(0, 0.5, 'TB')
